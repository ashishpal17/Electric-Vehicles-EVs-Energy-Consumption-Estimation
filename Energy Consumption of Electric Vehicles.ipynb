# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import pprint

# %%
df = pd.read_csv("C:/Users/ashis/Desktop/Dataset/VED.csv")

# %%
df
# Out:
#          DayNum  VehId  Trip  Timestamp(ms)  Latitude[deg]  Longitude[deg]  \
# 0      1.719774     10  1558              0      42.277066      -83.763404
# 1      1.719774     10  1558            200      42.277066      -83.763404
# 2      1.719774     10  1558           1200      42.277066      -83.763404
# 3      1.719774     10  1558           1500      42.277066      -83.763404
# 4      1.719774     10  1558           2300      42.277066      -83.763404
# ...         ...    ...   ...            ...            ...             ...
# 42142  7.613748    569   316         103600      42.306532      -83.707622
# 42143  7.613748    569   316         104600      42.306532      -83.707622
# 42144  7.613748    569   316         105700      42.306532      -83.707622
# 42145  7.613748    569   316         106500      42.306532      -83.707622
# 42146  7.613748    569   316         106700      42.306532      -83.707622
#
#        Vehicle Speed[km/h]  MAF[g/sec]  Engine RPM[RPM]  Absolute Load[%]  \
# 0                53.590000         NaN              NaN               NaN
# 1                51.980000         NaN              NaN               NaN
# 2                50.369999         NaN              NaN               NaN
# 3                50.369999         NaN              NaN               NaN
# 4                49.799999         NaN              NaN               NaN
# ...                    ...         ...              ...               ...
# 42142            53.484375         NaN              0.0               NaN
# 42143            52.765625         NaN              0.0               NaN
# 42144            52.046875         NaN              0.0               NaN
# 42145            52.046875         NaN              0.0               NaN
# 42146            50.953125         NaN              0.0               NaN
#
#        ...  Air Conditioning Power[kW]  Air Conditioning Power[Watts]  \
# 0      ...                         NaN                            0.0
# 1      ...                         NaN                            0.0
# 2      ...                         NaN                            0.0
# 3      ...                         NaN                            0.0
# 4      ...                         NaN                            0.0
# ...    ...                         ...                            ...
# 42142  ...                         0.0                            NaN
# 42143  ...                         0.0                            NaN
# 42144  ...                         0.0                            NaN
# 42145  ...                         0.0                            NaN
# 42146  ...                         0.0                            NaN
#
#        Heater Power[Watts]  HV_Battery_Current  HV_Battery_SOC  \
# 0                   2250.0               -21.5       96.341469
# 1                   2250.0               -21.5       96.341469
# 2                   2250.0               -21.5       96.341469
# 3                   2250.0                23.5       96.341469
# 4                   2250.0                23.5       96.341469
# ...                    ...                 ...             ...
# 42142                  NaN                 1.8       94.117676
# 42143                  NaN                 1.8       94.117676
# 42144                  NaN                 1.8       94.117676
# 42145                  NaN                 1.5       94.117676
# 42146                  NaN                 1.5       94.117676
#
#        HV_Battery_Voltage  Short Term Fuel Trim Bank 1[%]  \
# 0                 386.000                             NaN
# 1                 386.000                             NaN
# 2                 386.000                             NaN
# 3                 390.500                             NaN
# 4                 390.500                             NaN
# ...                   ...                             ...
# 42142             382.375                             NaN
# 42143             382.375                             NaN
# 42144             382.375                             NaN
# 42145             382.750                             NaN
# 42146             382.750                             NaN
#
#        Short Term Fuel Trim Bank 2[%]  Long Term Fuel Trim Bank 1[%]  \
# 0                                 NaN                            NaN
# 1                                 NaN                            NaN
# 2                                 NaN                            NaN
# 3                                 NaN                            NaN
# 4                                 NaN                            NaN
# ...                               ...                            ...
# 42142                             NaN                            NaN
# 42143                             NaN                            NaN
# 42144                             NaN                            NaN
# 42145                             NaN                            NaN
# 42146                             NaN                            NaN
#
#        Long Term Fuel Trim Bank 2[%]
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 42142                            NaN
# 42143                            NaN
# 42144                            NaN
# 42145                            NaN
# 42146                            NaN
#
# [42147 rows x 22 columns]

# %%
print("="*50)
print("Input Data Information","\n")
print(df.info())
# Out:
# ==================================================
# Input Data Information
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42147 entries, 0 to 42146
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   DayNum                          42147 non-null  float64
#  1   VehId                           42147 non-null  int64
#  2   Trip                            42147 non-null  int64
#  3   Timestamp(ms)                   42147 non-null  int64
#  4   Latitude[deg]                   42147 non-null  float64
#  5   Longitude[deg]                  42147 non-null  float64
#  6   Vehicle Speed[km/h]             42147 non-null  float64
#  7   MAF[g/sec]                      24129 non-null  float64
#  8   Engine RPM[RPM]                 38514 non-null  float64
#  9   Absolute Load[%]                0 non-null      float64
#  10  OAT[DegC]                       42147 non-null  float64
#  11  Fuel Rate[L/hr]                 14385 non-null  float64
#  12  Air Conditioning Power[kW]      14385 non-null  float64
#  13  Air Conditioning Power[Watts]   27762 non-null  float64
#  14  Heater Power[Watts]             3633 non-null   float64
#  15  HV_Battery_Current              42147 non-null  float64
#  16  HV_Battery_SOC                  42147 non-null  float64
#  17  HV_Battery_Voltage              42147 non-null  float64
#  18  Short Term Fuel Trim Bank 1[%]  0 non-null      float64
#  19  Short Term Fuel Trim Bank 2[%]  0 non-null      float64
#  20  Long Term Fuel Trim Bank 1[%]   0 non-null      float64
#  21  Long Term Fuel Trim Bank 2[%]   0 non-null      float64
# dtypes: float64(19), int64(3)
# memory usage: 7.1 MB
# None

# %%
plt.figure(figsize=(18,9))
plt.plot( df.HV_Battery_SOC,  df.HV_Battery_Current)
plt.xlabel("HV_Battery_SOC")
plt.ylabel("HV_Battery_Current")
plt.show()

# %%
from matplotlib import style
fig = plt.figure()
ax1 = plt.subplot2grid((1,1), (0,0))
style.use('ggplot')
sns.lineplot(x=df["HV_Battery_SOC"], y=df["HV_Battery_Current"], data=df)
sns.set(rc={'figure.figsize':(10,8)})
plt.xlabel("HV_Battery_SOC in %")
plt.ylabel("HV_Battery_Current")
plt.grid(True)
plt.legend()
for label in ax1.xaxis.get_ticklabels():
    label.set_rotation(90)
plt.title("Energy Consumption")
# Out:
# No handles with labels found to put in legend.
# Text(0.5, 1.0, 'Energy Consumption')

# %%
from matplotlib import style

fig = plt.figure()
ax1 = plt.subplot2grid((1,1), (0,0))

style.use('ggplot')

sns.lineplot(x=df["HV_Battery_SOC"], y=df["VehId"], data=df)
sns.set(rc={'figure.figsize':(15,6)})

plt.title("Energy consumptionnin")
plt.xlabel("HV_Battery_SOC in %")
plt.ylabel("Vehicle Id")
plt.grid(True)
plt.legend()

for label in ax1.xaxis.get_ticklabels():
    label.set_rotation(90)


plt.title("Energy Consumption")
# Out:
# No handles with labels found to put in legend.
# Text(0.5, 1.0, 'Energy Consumption')

# %%
sns.distplot(df["HV_Battery_SOC"])
plt.title("Energy Distribution for State of Charge")
# Out:
# C:\Users\ashis\.conda\envs\tensorflow_keras\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Energy Distribution for State of Charge')

# %%
sns.distplot(df["HV_Battery_Current"])
plt.title("Energy Distribution for Current Battery State")
# Out:
# C:\Users\ashis\.conda\envs\tensorflow_keras\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Energy Distribution for Current Battery State')

# %%
# Energy with Respect to Time
fig = plt.figure()
ax1= fig.add_subplot(111)
sns.lineplot(x=df["HV_Battery_Voltage"],y=df["HV_Battery_SOC"], data=df)
plt.title("Battery Voltage of Car vs State of Charge of Battery Voltage")
plt.xlabel("HV_Battery_Voltage")
plt.grid(True, alpha=1)
plt.legend()

for label in ax1.xaxis.get_ticklabels():
    label.set_rotation(90)
# Out:
# No handles with labels found to put in legend.

# %%
print("Dataset ",df.shape )
# Out:
# Dataset  (42147, 22)

# %%
TestData = df.tail(100)

Training_Set = df.iloc[:,0:1]

Training_Set = Training_Set[:-60]

# %%
print("Training Set Shape ", Training_Set.shape)
print("Test Set Shape ", TestData.shape)
# Out:
# Training Set Shape  (42087, 1)
# Test Set Shape  (100, 22)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
sc = MinMaxScaler(feature_range=(0, 1))
Train = sc.fit_transform(Training_Set)

# %%
Training_Set = Training_Set.values

# %%
Training_Set
# Out:
# array([[1.71977381],
#        [1.71977381],
#        [1.71977381],
#        ...,
#        [7.61374849],
#        [7.61374849],
#        [7.61374849]])

# %%
Train
# Out:
# array([[0.10245255],
#        [0.10245255],
#        [0.10245255],
#        ...,
#        [0.94483885],
#        [0.94483885],
#        [0.94483885]])

# %%
X_Train = []
Y_Train = []

# Range should be fromm 60 Values to END 
for i in range(60, Train.shape[0]):
    
    # X_Train 0-59 
    X_Train.append(Train[i-60:i])
    
    # Y Would be 60 th Value based on past 60 Values 
    Y_Train.append(Train[i])

# Convert into Numpy Array
X_Train = np.array(X_Train)
Y_Train = np.array(Y_Train)

print(X_Train.shape)
print(Y_Train.shape)
# Out:
# (42027, 60, 1)
# (42027, 1)

# %%
# Shape should be Number of [Datapoints , Steps , 1 )
# we convert into 3-d Vector or #rd Dimesnsion
X_Train = np.reshape(X_Train, newshape=(X_Train.shape[0], X_Train.shape[1], 1))
X_Train.shape
# Out:
# (42027, 60, 1)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import LSTM
from keras.layers import Dropout

# %%
regressor = Sequential()

# Adding the first LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_Train.shape[1], 1)))
regressor.add(Dropout(0.2))

# Adding a second LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

# Adding a third LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

# Adding a fourth LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))

# Adding the output layer
regressor.add(Dense(units = 1))

# Compiling the RNN
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
regressor.fit(X_Train, Y_Train, epochs = 50, batch_size = 32)
# Out:
# Epoch 1/50
# 1314/1314 [==============================] - 182s 138ms/step - loss: 0.0036
# Epoch 2/50
# 1314/1314 [==============================] - 202s 154ms/step - loss: 0.0015
# Epoch 3/50
# 1314/1314 [==============================] - 202s 154ms/step - loss: 9.8458e-04
# Epoch 4/50
# 1314/1314 [==============================] - 202s 154ms/step - loss: 7.9681e-04
# Epoch 5/50
# 1314/1314 [==============================] - 201s 153ms/step - loss: 6.5795e-04
# Epoch 6/50
# 1314/1314 [==============================] - 200s 152ms/step - loss: 6.2859e-04
# Epoch 7/50
# 1314/1314 [==============================] - 183s 140ms/step - loss: 5.9928e-04
# Epoch 8/50
# 1314/1314 [==============================] - 85s 65ms/step - loss: 5.9135e-04
# Epoch 9/50
# 1314/1314 [==============================] - 86s 66ms/step - loss: 5.4762e-04
# Epoch 10/50
# 1314/1314 [==============================] - 84s 64ms/step - loss: 5.2965e-04
# Epoch 11/50
# 1314/1314 [==============================] - 84s 64ms/step - loss: 5.2850e-04
# Epoch 12/50
# 1314/1314 [==============================] - 85s 65ms/step - loss: 5.3074e-04
# Epoch 13/50
# 1314/1314 [==============================] - 86s 66ms/step - loss: 5.1447e-04
# Epoch 14/50
# 1314/1314 [==============================] - 85s 65ms/step - loss: 5.1039e-04
# Epoch 15/50
# 1314/1314 [==============================] - 85s 65ms/step - loss: 5.0422e-04
# Epoch 16/50
# 1314/1314 [==============================] - 85s 65ms/step - loss: 4.9507e-04
# Epoch 17/50
# 1314/1314 [==============================] - 87s 66ms/step - loss: 4.8552e-04
# Epoch 18/50
# 1314/1314 [==============================] - 86s 65ms/step - loss: 4.7730e-04
# Epoch 19/50
# 1314/1314 [==============================] - 85s 65ms/step - loss: 4.8053e-04
# Epoch 20/50
# 1314/1314 [==============================] - 86s 65ms/step - loss: 4.7988e-04
# Epoch 21/50
# 1314/1314 [==============================] - 85s 65ms/step - loss: 4.7509e-04
# Epoch 22/50
# 1314/1314 [==============================] - 87s 66ms/step - loss: 4.7247e-04
# Epoch 23/50
# 1314/1314 [==============================] - 86s 65ms/step - loss: 4.7631e-04
# Epoch 24/50
# 1314/1314 [==============================] - 87s 66ms/step - loss: 4.7179e-04
# Epoch 25/50
# 1314/1314 [==============================] - 86s 65ms/step - loss: 4.6245e-04
# Epoch 26/50
# 1314/1314 [==============================] - 86s 66ms/step - loss: 4.6066e-04
# Epoch 27/50
# 1314/1314 [==============================] - 86s 65ms/step - loss: 4.5421e-04
# Epoch 28/50
# 1314/1314 [==============================] - 86s 65ms/step - loss: 4.4976e-04
# Epoch 29/50
# 1314/1314 [==============================] - 85s 65ms/step - loss: 4.5920e-04
# Epoch 30/50
# 1314/1314 [==============================] - 86s 66ms/step - loss: 4.5425e-04
# Epoch 31/50
# 1314/1314 [==============================] - 86s 65ms/step - loss: 4.4123e-04
# Epoch 32/50
# 1314/1314 [==============================] - 87s 66ms/step - loss: 4.4275e-04
# Epoch 33/50
# 1314/1314 [==============================] - 86s 66ms/step - loss: 4.4597e-04
# Epoch 34/50
# 1314/1314 [==============================] - 87s 66ms/step - loss: 4.4349e-04
# Epoch 35/50
# 1314/1314 [==============================] - 85s 65ms/step - loss: 4.3931e-04
# Epoch 36/50
# 1314/1314 [==============================] - 86s 65ms/step - loss: 4.3761e-04
# Epoch 37/50
# 1314/1314 [==============================] - 86s 65ms/step - loss: 4.4554e-04
# Epoch 38/50
# 1314/1314 [==============================] - 86s 66ms/step - loss: 4.3043e-04
# Epoch 39/50
# 1314/1314 [==============================] - 86s 65ms/step - loss: 4.4015e-04
# Epoch 40/50
# 1314/1314 [==============================] - 181s 138ms/step - loss: 4.3681e-04
# Epoch 41/50
# 1314/1314 [==============================] - 208s 158ms/step - loss: 4.2833e-04
# Epoch 42/50
# 1314/1314 [==============================] - 208s 158ms/step - loss: 4.2468e-04
# Epoch 43/50
# 1314/1314 [==============================] - 191s 146ms/step - loss: 4.4112e-04
# Epoch 44/50
# 1314/1314 [==============================] - 201s 153ms/step - loss: 4.3515e-04
# Epoch 45/50
# 1314/1314 [==============================] - 204s 155ms/step - loss: 4.2863e-04
# Epoch 46/50
# 1314/1314 [==============================] - 208s 158ms/step - loss: 4.2272e-04
# Epoch 47/50
# 1314/1314 [==============================] - 208s 158ms/step - loss: 4.2960e-04
# Epoch 48/50
# 1314/1314 [==============================] - 164s 125ms/step - loss: 4.2356e-04
# Epoch 49/50
# 1314/1314 [==============================] - 198s 150ms/step - loss: 4.3271e-04
# Epoch 50/50
# 1314/1314 [==============================] - 204s 155ms/step - loss: 4.2715e-04

# %%
TestData.head(2)
# Out:
#          DayNum  VehId  Trip  Timestamp(ms)  Latitude[deg]  Longitude[deg]  \
# 42047  7.613748    569   316          32700      42.315743      -83.707303
# 42048  7.613748    569   316          33700      42.315743      -83.707303
#
#        Vehicle Speed[km/h]  MAF[g/sec]  Engine RPM[RPM]  Absolute Load[%]  \
# 42047            45.015625         NaN              0.0               NaN
# 42048            45.625000         NaN              0.0               NaN
#
#        ...  Air Conditioning Power[kW]  Air Conditioning Power[Watts]  \
# 42047  ...                         0.4                            NaN
# 42048  ...                         0.4                            NaN
#
#        Heater Power[Watts]  HV_Battery_Current  HV_Battery_SOC  \
# 42047                  NaN          -26.400002       95.294151
# 42048                  NaN          -26.400002       95.294151
#
#        HV_Battery_Voltage  Short Term Fuel Trim Bank 1[%]  \
# 42047             378.875                             NaN
# 42048             378.875                             NaN
#
#        Short Term Fuel Trim Bank 2[%]  Long Term Fuel Trim Bank 1[%]  \
# 42047                             NaN                            NaN
# 42048                             NaN                            NaN
#
#        Long Term Fuel Trim Bank 2[%]
# 42047                            NaN
# 42048                            NaN
#
# [2 rows x 22 columns]

# %%
TestData.shape
# Out:
# (100, 22)

# %%
df.shape
# Out:
# (42147, 22)

# %%
Df_Total = pd.concat((df[["HV_Battery_SOC"]], TestData[["HV_Battery_SOC"]]), axis=0)

# %%
Df_Total.shape
# Out:
# (42247, 1)

# %%
inputs = Df_Total[len(Df_Total) - len(TestData) - 60:].values
inputs.shape
# Out:
# (160, 1)

# %%
inputs = Df_Total[len(Df_Total) - len(TestData) - 60:].values

# We need to Reshape
inputs = inputs.reshape(-1,1)

# Normalize the Dataset
inputs = sc.transform(inputs)

X_test = []
for i in range(60, 160):
    X_test.append(inputs[i-60:i])
    
# Convert into Numpy Array
X_test = np.array(X_test)

# Reshape before Passing to Network
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Pass to Model 
predicted_Soc_ = regressor.predict(X_test)

# Do inverse Transformation to get Values 
predicted_Soc_ = sc.inverse_transform(predicted_Soc_)

# %%
True_Soc = TestData["HV_Battery_SOC"].to_list()
True_Soc  = predicted_Soc_ 
dates = TestData.index.to_list()

# %%
Machine_Df = pd.DataFrame(data={
    "TrueSoc": True_Soc,
    "PredictedSoc":[x[0] for x in Predicted_Soc]
})

# %%
# Future Predicted
Machine_Df
# Out:
#       TrueSoc  PredictedSoc
# 0   95.294151     96.998634
# 1   95.294151     96.998634
# 2   95.294151     96.998642
# 3   95.294151     96.998642
# 4   95.294151     96.998642
# ..        ...           ...
# 95  94.117676     96.998627
# 96  94.117676     96.998634
# 97  94.117676     96.998627
# 98  94.117676     96.998627
# 99  94.117676     96.998634
#
# [100 rows x 2 columns]

# %%
True_Soc
# Out:
# [95.29415136,
#  95.29415136,
#  95.29415136,
#  95.29415136,
#  95.29415136,
#  95.29415136,
#  95.29415136,
#  95.29415136,
#  95.29415136,
#  95.29415136,
#  95.29415136,
#  95.29415136,
#  95.29415136,
#  95.29415136,
#  95.29415136,
#  95.29415136,
#  95.29415136,
#  95.29415136,
#  95.29415136,
#  95.29415136,
#  95.29415136,
#  95.29415136,
#  95.29415136,
#  95.29415136,
#  95.29415136,
#  95.29415136,
#  95.29415136,
#  95.29415136,
#  95.29415136,
#  95.29415136,
#  95.29415136,
#  95.29415136,
#  95.29415136,
#  95.29415136,
#  95.29415136,
#  95.29415136,
#  95.29415136,
#  95.29415136,
#  95.29415136,
#  95.29415136,
#  95.29415136,
#  95.29415136,
#  95.29415136,
#  95.29415136,
#  95.29415136,
#  95.29415136,
#  95.29415136,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578,
#  94.11767578]

# %%
Predicted_Soc
# Out:
# array([[96.998634],
#        [96.998634],
#        [96.99864 ],
#        [96.99864 ],
#        [96.99864 ],
#        [96.99864 ],
#        [96.99864 ],
#        [96.99864 ],
#        [96.99864 ],
#        [96.99864 ],
#        [96.99864 ],
#        [96.99864 ],
#        [96.99864 ],
#        [96.99864 ],
#        [96.99864 ],
#        [96.99864 ],
#        [96.99864 ],
#        [96.99864 ],
#        [96.99864 ],
#        [96.99864 ],
#        [96.99864 ],
#        [96.99864 ],
#        [96.99864 ],
#        [96.99864 ],
#        [96.99864 ],
#        [96.99864 ],
#        [96.99864 ],
#        [96.99864 ],
#        [96.99864 ],
#        [96.99864 ],
#        [96.99864 ],
#        [96.99864 ],
#        [96.99864 ],
#        [96.99864 ],
#        [96.99864 ],
#        [96.99864 ],
#        [96.99864 ],
#        [96.99864 ],
#        [96.99864 ],
#        [96.99864 ],
#        [96.99864 ],
#        [96.99864 ],
#        [96.99864 ],
#        [96.99864 ],
#        [96.99864 ],
#        [96.99864 ],
#        [96.99864 ],
#        [96.99864 ],
#        [96.998634],
#        [96.998634],
#        [96.99863 ],
#        [96.998634],
#        [96.998634],
#        [96.99863 ],
#        [96.99863 ],
#        [96.998634],
#        [96.99863 ],
#        [96.998634],
#        [96.99863 ],
#        [96.99863 ],
#        [96.99863 ],
#        [96.998634],
#        [96.998634],
#        [96.99863 ],
#        [96.99863 ],
#        [96.998634],
#        [96.99863 ],
#        [96.99863 ],
#        [96.99863 ],
#        [96.998634],
#        [96.99863 ],
#        [96.998634],
#        [96.99863 ],
#        [96.99863 ],
#        [96.99863 ],
#        [96.99863 ],
#        [96.998634],
#        [96.99863 ],
#        [96.99863 ],
#        [96.99863 ],
#        [96.998634],
#        [96.998634],
#        [96.998634],
#        [96.998634],
#        [96.998634],
#        [96.998634],
#        [96.998634],
#        [96.998634],
#        [96.99863 ],
#        [96.998634],
#        [96.998634],
#        [96.998634],
#        [96.998634],
#        [96.998634],
#        [96.998634],
#        [96.99863 ],
#        [96.998634],
#        [96.99863 ],
#        [96.99863 ],
#        [96.998634]], dtype=float32)

# %%
fig = plt.figure()

ax1= fig.add_subplot(111)

x = dates
y = True_Soc

y1 = Predicted_Soc

plt.plot(x,y, color="green")
plt.plot(x,y1, color="red")
# beautify the x-labels
plt.gcf().autofmt_xdate()
plt.xlabel('Dates')
plt.ylabel("HV_Battery_SOC")
plt.title("Machine Learned the Pattern Predicting Future Values ")
plt.legend()
# Out:
# No handles with labels found to put in legend.
